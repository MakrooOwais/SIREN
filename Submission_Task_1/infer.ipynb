# %%
from model import Classifier
from config import Config
from torchvision import transforms

# %%
conf = Config()
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]
transform = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Resize((224, 224), antialias=True),
        transforms.Normalize(mean=mean, std=std),
    ]
)

model = Classifier().to(conf.device)
model.eval()
# Out:
# Classifier(
#   (accuracy): BinaryAccuracy()
#   (loss_fn): BCEWithLogitsLoss()
#   (backbone): EfficientNet(
#     (features): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (2): SiLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): FusedMBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (1): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#         )
#         (1): FusedMBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
# ...

# %%
import os
from PIL import Image
path = "/home/owais/The_DumbOne/InterIIT/Final_Inference/perturbed_images_32"
results = []
from tqdm import tqdm
import torch
with torch.no_grad():
    for img in tqdm(os.listdir(path)):
        format_res = {"index": int(img[:-len(".png")])}
        image = Image.open(path+"/" + img)
        scores = model(transform(image).unsqueeze(0).to(conf.device)).squeeze().cpu()
        cls = conf.idx2lbl[scores.argmax().cpu().item()]
        format_res["prediction"] = cls
        results.append(format_res)
import json

with open("results.json", "w") as f:
    json.dump(results, f, indent=4)
# Out:
#  99%|█████████▉| 300/302 [03:43<00:01,  1.34it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 9
#       7 with torch.no_grad():
#       8     for img in tqdm(os.listdir(path)):
# ----> 9         format_res = {"index": int(img[:-len(".png")])}
#      10         image = Image.open(path+"/" + img)
#      11         scores = model(transform(image).unsqueeze(0).to(conf.device)).squeeze().cpu()
#
# ValueError: invalid literal for int() with base 10: 'perturbed_real_7_222-checkpoint'

# %%
import json
with open("results.json", "w") as f:
    json.dump(results, f, indent=4)
